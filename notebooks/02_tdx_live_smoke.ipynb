# %% [markdown]
# # TripScore — TDX Live Smoke Check
#
# This notebook calls the real TDX APIs and prints counts to confirm credentials + datasets work.
#
# Requirements:
# - `TDX_CLIENT_ID` / `TDX_CLIENT_SECRET` configured in the environment
# - network access

# %%
from json import load
import os
import sys
from pathlib import Path

def find_repo_root(start: Path) -> Path:
    p = start.resolve()
    for _ in range(10):
        if (p / "src").exists() and (p / "src" / "tripscore").exists():
            return p
        if (p / ".git").exists():
            return p
        if (p / ".env").exists():
            return p
        p = p.parent
    return start.resolve()

repo_root = find_repo_root(Path.cwd())
src_dir = repo_root / "src"
if src_dir.exists():
    sys.path.insert(0, str(src_dir))

from tripscore.core.env import load_dotenv_if_present
load_dotenv_if_present()

print('TDX_CLIENT_ID configured:', bool(os.getenv('TDX_CLIENT_ID')))
print('TDX_CLIENT_SECRET configured:', bool(os.getenv('TDX_CLIENT_SECRET')))
# Out:
# TDX_CLIENT_ID configured: True
# TDX_CLIENT_SECRET configured: True

# %%
from pathlib import Path

from tripscore.config.settings import get_settings
from tripscore.core.cache import FileCache
from tripscore.ingestion.tdx_client import TdxClient

settings = get_settings()
cache = FileCache(Path(settings.cache.dir), enabled=settings.cache.enabled)
tdx = TdxClient(settings, cache)

print('TDX city:', settings.ingestion.tdx.city)
# Out:
# TDX city: Taipei

# %%
# Bus stops
bus_stops = tdx.get_bus_stops()
print('Bus stops:', len(bus_stops))
print('Example:', bus_stops[0])
# Out:
# TDX request failed with status=429; retrying in 25.00s (attempt 1/6)
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/web-projects/tripscore/src/tripscore/ingestion/tdx_client.py:167, in TdxClient._tdx_get_json(self, url, params)
#     166     self._throttle_requests()
# --> 167     return get_json(
#     168         url,
#     169         params=params,
#     170         headers=headers,
#     171         timeout_seconds=self._settings.app.http_timeout_seconds,
#     172     )
#     173 except httpx.HTTPStatusError as exc:
#
# File ~/web-projects/tripscore/src/tripscore/core/http.py:41, in get_json(url, params, headers, timeout_seconds)
#      40 resp = client.get(url, params=params, headers=request_headers)
# ---> 41 resp.raise_for_status()
#      42 return resp.json()
#
# File ~/miniconda3/envs/ai_env/lib/python3.10/site-packages/httpx/_models.py:749, in Response.raise_for_status(self)
#     748 message = message.format(self, error_type=error_type)
# --> 749 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '429 Too Many Requests' for url 'https://tdx.transportdata.tw/api/basic/v2/Bus/Stop/City/Taipei?%24format=JSON&%24top=1000&%24skip=0&%24select=StopUID%2CStopName%2CStopPosition'
# For more information check: https://httpstatuses.com/429
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Bus stops
# ----> 2 bus_stops = tdx.get_bus_stops()
#       3 print('Bus stops:', len(bus_stops))
#       4 print('Example:', bus_stops[0])
#
# File ~/web-projects/tripscore/src/tripscore/ingestion/tdx_client.py:303, in TdxClient.get_bus_stops(self, city)
#     300     logger.info("Fetching TDX bus stops for city=%s", city)
#     301     return self._fetch_bus_stops_raw(city)
# --> 303 raw = self._cache.get_or_set(
#     304     "tdx",
#     305     cache_key,
#     306     builder,
#     307     ttl_seconds=self._settings.ingestion.tdx.cache_ttl_seconds,
#     308     stale_if_error=True,
#     309     stale_predicate=self._stale_ok,
#     310 )
#     312 stops: list[BusStop] = []
#     313 for item in raw:
#
# File ~/web-projects/tripscore/src/tripscore/core/cache.py:145, in FileCache.get_or_set(self, namespace, key, builder, ttl_seconds, stale_if_error, stale_predicate)
#     143     return cached
#     144 try:
# --> 145     value = builder()
#     146 except Exception as exc:
#     147     if stale_if_error and (stale_predicate(exc) if stale_predicate else True):
#
# File ~/web-projects/tripscore/src/tripscore/ingestion/tdx_client.py:301, in TdxClient.get_bus_stops.<locals>.builder()
#     299 def builder() -> list[dict[str, Any]]:
#     300     logger.info("Fetching TDX bus stops for city=%s", city)
# --> 301     return self._fetch_bus_stops_raw(city)
#
# File ~/web-projects/tripscore/src/tripscore/ingestion/tdx_client.py:227, in TdxClient._fetch_bus_stops_raw(self, city)
#     225 top = self._settings.ingestion.tdx.bus_stops.top
#     226 select = self._settings.ingestion.tdx.bus_stops.select
# --> 227 return self._fetch_paged_list(endpoint, top=top, select=select)
#
# File ~/web-projects/tripscore/src/tripscore/ingestion/tdx_client.py:271, in TdxClient._fetch_paged_list(self, endpoint, top, select)
#     269 while True:
#     270     params = {"$format": "JSON", "$top": top, "$skip": skip, "$select": select}
# --> 271     page = self._tdx_get_json(endpoint, params=params)
#     272     if not isinstance(page, list):
#     273         raise RuntimeError("Unexpected TDX response shape; expected a list.")
#
# File ~/web-projects/tripscore/src/tripscore/ingestion/tdx_client.py:202, in TdxClient._tdx_get_json(self, url, params)
#     193         delay = max(delay, retry_after)
#     195     logger.warning(
#     196         "TDX request failed with status=%s; retrying in %.2fs (attempt %s/%s)",
#     197         status,
#    (...)
#     200         max_attempts,
#     201     )
# --> 202     time.sleep(delay)
#     203     continue
#     204 except httpx.TransportError as exc:
#
# KeyboardInterrupt:

# %%
# YouBike
bike = tdx.get_youbike_station_statuses()
print('Bike stations:', len(bike))
print('Example:', bike[0])
# Out:
# TDX request failed with status=429; retrying in 18.00s (attempt 1/6)
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/web-projects/tripscore/src/tripscore/ingestion/tdx_client.py:167, in TdxClient._tdx_get_json(self, url, params)
#     166     self._throttle_requests()
# --> 167     return get_json(
#     168         url,
#     169         params=params,
#     170         headers=headers,
#     171         timeout_seconds=self._settings.app.http_timeout_seconds,
#     172     )
#     173 except httpx.HTTPStatusError as exc:
#
# File ~/web-projects/tripscore/src/tripscore/core/http.py:41, in get_json(url, params, headers, timeout_seconds)
#      40 resp = client.get(url, params=params, headers=request_headers)
# ---> 41 resp.raise_for_status()
#      42 return resp.json()
#
# File ~/miniconda3/envs/ai_env/lib/python3.10/site-packages/httpx/_models.py:749, in Response.raise_for_status(self)
#     748 message = message.format(self, error_type=error_type)
# --> 749 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '429 Too Many Requests' for url 'https://tdx.transportdata.tw/api/basic/v2/Bike/Station/City/Taipei?%24format=JSON&%24top=1000&%24skip=0&%24select=StationUID%2CStationName%2CStationPosition'
# For more information check: https://httpstatuses.com/429
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # YouBike
# ----> 2 bike = tdx.get_youbike_station_statuses()
#       3 print('Bike stations:', len(bike))
#       4 print('Example:', bike[0])
#
# File ~/web-projects/tripscore/src/tripscore/ingestion/tdx_client.py:382, in TdxClient.get_youbike_station_statuses(self, city)
#     379     logger.info("Fetching TDX bike availability for city=%s", city)
#     380     return self._fetch_bike_availability_raw(city)
# --> 382 raw_stations = self._cache.get_or_set(
#     383     "tdx",
#     384     stations_cache_key,
#     385     stations_builder,
#     386     ttl_seconds=self._settings.ingestion.tdx.cache_ttl_seconds,
#     387     stale_if_error=True,
#     388     stale_predicate=self._stale_ok,
#     389 )
#     390 raw_availability = self._cache.get_or_set(
#     391     "tdx",
#     392     availability_cache_key,
#    (...)
#     396     stale_predicate=self._stale_ok,
#     397 )
#     399 availability_by_uid: dict[str, tuple[int | None, int | None]] = {}
#
# File ~/web-projects/tripscore/src/tripscore/core/cache.py:145, in FileCache.get_or_set(self, namespace, key, builder, ttl_seconds, stale_if_error, stale_predicate)
#     143     return cached
#     144 try:
# --> 145     value = builder()
#     146 except Exception as exc:
#     147     if stale_if_error and (stale_predicate(exc) if stale_predicate else True):
#
# File ~/web-projects/tripscore/src/tripscore/ingestion/tdx_client.py:376, in TdxClient.get_youbike_station_statuses.<locals>.stations_builder()
#     374 def stations_builder() -> list[dict[str, Any]]:
#     375     logger.info("Fetching TDX bike stations for city=%s", city)
# --> 376     return self._fetch_bike_stations_raw(city)
#
# File ~/web-projects/tripscore/src/tripscore/ingestion/tdx_client.py:234, in TdxClient._fetch_bike_stations_raw(self, city)
#     232 top = self._settings.ingestion.tdx.bike_stations.top
#     233 select = self._settings.ingestion.tdx.bike_stations.select
# --> 234 return self._fetch_paged_list(endpoint, top=top, select=select)
#
# File ~/web-projects/tripscore/src/tripscore/ingestion/tdx_client.py:271, in TdxClient._fetch_paged_list(self, endpoint, top, select)
#     269 while True:
#     270     params = {"$format": "JSON", "$top": top, "$skip": skip, "$select": select}
# --> 271     page = self._tdx_get_json(endpoint, params=params)
#     272     if not isinstance(page, list):
#     273         raise RuntimeError("Unexpected TDX response shape; expected a list.")
#
# File ~/web-projects/tripscore/src/tripscore/ingestion/tdx_client.py:202, in TdxClient._tdx_get_json(self, url, params)
#     193         delay = max(delay, retry_after)
#     195     logger.warning(
#     196         "TDX request failed with status=%s; retrying in %.2fs (attempt %s/%s)",
#     197         status,
#    (...)
#     200         max_attempts,
#     201     )
# --> 202     time.sleep(delay)
#     203     continue
#     204 except httpx.TransportError as exc:
#
# KeyboardInterrupt:

# %%
# Metro
metro = tdx.get_metro_stations()
print('Metro stations:', len(metro))
print('Example:', metro[0])

# %%
# Parking (may be empty depending on dataset availability for the selected city)
parking = tdx.get_parking_lot_s tatuses()
print('Parking lots:', len(parking))
print('Example:', parking[0] if parking else None)
